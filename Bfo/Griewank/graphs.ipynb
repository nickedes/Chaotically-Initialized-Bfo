# %%
data = {"1": [[4.440892098500626e-16, 200], [4.440892098500626e-16, 400], [4.440892098500626e-16, 600], [4.440892098500626e-16, 800], [4.440892098500626e-16, 1000], [4.440892098500626e-16, 1200]], "10": [[0.03431013461245802, 200], [0.01529714456887088, 400], [0.006225547209151694, 600], [0.006225547209151694, 800], [0.006225547209151694, 1000], [0.006225547209151694, 1200]], "2": [[0.09617476107174372, 200], [0.09617476107174372, 400], [0.09617476107174372, 600], [0.09617476107174372, 800], [0.09617476107174372, 1000], [0.09617476107174372, 1200]], "3": [[0.00028042820746043695, 200], [0.00028042820746043695, 400], [0.00028042820746043695, 600], [0.00028042820746043695, 800], [0.00028042820746043695, 1000], [0.00028042820746043695, 1200]], "4": [[0.01424343113697657, 200], [0.01424343113697657, 400], [0.01424343113697657, 600], [0.01424343113697657, 800], [0.00824385072217182, 1000], [0.00824385072217182, 1200]], "5": [[0.00018866384658644542, 200], [0.00018866384658644542, 400], [1.4268044286724901e-05, 600], [1.4268044286724901e-05, 800], [1.4268044286724901e-05, 1000], [1.4268044286724901e-05, 1200]], "6": [[0.004883698936486325, 200], [0.004883698936486325, 400], [0.004883698936486325, 600], [0.000947322984603316, 800], [0.0006205475928950932, 1000], [0.0006205475928950932, 1200]], "7": [[7.345360628630004e-07, 200], [7.345360628630004e-07, 400], [7.094969574072962e-07, 600], [7.094969574072962e-07, 800], [6.258036311379556e-10, 1000], [6.258036311379556e-10, 1200]], "8": [[0.010163023359759493, 200], [0.010163023359759493, 400], [0.010163023359759493, 600], [0.010163023359759493, 800], [0.010163023359759493, 1000], [0.010163023359759493, 1200]], "9": [[3.0065890777031257e-08, 200], [3.0065890777031257e-08, 400], [3.0065890777031257e-08, 600], [3.0065890777031257e-08, 800], [3.0065890777031257e-08, 1000], [3.0065890777031257e-08, 1200]]}

# %%
import matplotlib.pyplot as plt
from math import e
e
# Out:
# 2.718281828459045

# %%
axes = plt.gca()
axes.set_xlim([200, 1200])
axes.set_ylim([e**-70,e**-(2.5)])
for x in data:
    best, iteration = [], []
    for value in data[x]:
        best.append(value[0])
        iteration.append(value[1])
    plt.plot(iteration, best, linewidth=1)
#     plt.legend(["logistic","chebyshev","gauss","piecewise","singer","tent","iterative","sine","circle","sinusoidal",], loc='upper right')
plt.savefig('graph.png')
plt.show()
