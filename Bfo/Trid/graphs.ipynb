# %%
data = {"1": [[0.0899800250874, 200], [0.0899800250874, 400], [0.0899800250874, 600], [0.0899800250874, 800], [0.0899800250874, 1000], [0.0899800250874, 1200]], "10": [[0.43254896061788783, 200], [0.43254896061788783, 400], [0.25254553339024055, 600], [0.08357068467086753, 800], [0.08357068467086753, 1000], [0.08357068467086753, 1200]], "2": [[0.11111111111111122, 200], [0.11111111111111122, 400], [0.11111111111111122, 600], [0.11111111111111122, 800], [0.11111111111111122, 1000], [0.11111111111111122, 1200]], "3": [[0.009582519531261324, 200], [0.009582519531261324, 400], [0.009582519531261324, 600], [0.009582519531261324, 800], [0.009582519531261324, 1000], [0.009582519531261324, 1200]], "4": [[0.026419997267493334, 200], [0.026419997267493334, 400], [0.026419997267493334, 600], [0.026419997267493334, 800], [0.026419997267493334, 1000], [0.026419997267493334, 1200]], "5": [[0.0051262356774349205, 200], [0.0051262356774349205, 400], [0.0051262356774349205, 600], [0.0051262356774349205, 800], [0.0051262356774349205, 1000], [0.0051262356774349205, 1200]], "6": [[0.004191565767365901, 200], [0.0005376300474910778, 400], [0.0005376300474910778, 600], [0.000363812748711112, 800], [5.66565575343958e-05, 1000], [5.66565575343958e-05, 1200]], "7": [[0.012463427566420437, 200], [0.012463427566420437, 400], [0.012463427566420437, 600], [0.012463427566420437, 800], [0.012463427566420437, 1000], [0.012463427566420437, 1200]], "8": [[0.02929242339158411, 200], [0.02929242339158411, 400], [0.02533430280593768, 600], [0.02533430280593768, 800], [0.02533430280593768, 1000], [0.02533430280593768, 1200]], "9": [[0.08058470265380835, 200], [0.08058470265380835, 400], [0.08058470265380835, 600], [0.08058470265380835, 800], [0.08058470265380835, 1000], [0.08058470265380835, 1200]]}

# %%
import matplotlib.pyplot as plt
from math import e
e
# Out:
# 2.718281828459045

# %%
axes = plt.gca()
axes.set_xlim([200, 1200])
axes.set_ylim([e**-70,e**-(2.5)])
for x in data:
    best, iteration = [], []
    for value in data[x]:
        best.append(value[0])
        iteration.append(value[1])
    plt.plot(iteration, best, linewidth=1)
#     plt.legend(["logistic","chebyshev","gauss","piecewise","singer","tent","iterative","sine","circle","sinusoidal",], loc='upper right')
plt.savefig('graph.png')
plt.show()
