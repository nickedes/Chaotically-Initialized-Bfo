# %%
data = {"1": [[1.7763568394002505e-15, 200], [1.7763568394002505e-15, 400], [1.7763568394002505e-15, 600], [1.7763568394002505e-15, 800], [1.7763568394002505e-15, 1000], [1.7763568394002505e-15, 1200]], "10": [[0.007478991406802082, 200], [0.0008481457288054828, 400], [0.0001681267508062967, 600], [0.0001681267508062967, 800], [0.0001681267508062967, 1000], [0.0001681267508062967, 1200]], "2": [[0.05983684907656461, 200], [0.05983684907656461, 400], [0.05983684907656461, 600], [0.05983684907656461, 800], [0.05983684907656461, 1000], [0.05983684907656461, 1200]], "3": [[1.955108024531693e-06, 200], [1.955108024531693e-06, 400], [1.955108024531693e-06, 600], [1.955108024531693e-06, 800], [1.955108024531693e-06, 1000], [1.955108024531693e-06, 1200]], "4": [[0.003203421944779128, 200], [0.003203421944779128, 400], [0.003203421944779128, 600], [0.003203421944779128, 800], [0.0010867436661299856, 1000], [0.0010867436661299856, 1200]], "5": [[8.895678238474147e-07, 200], [8.895678238474147e-07, 400], [4.475795717384656e-08, 600], [4.475795717384656e-08, 800], [4.475795717384656e-08, 1000], [4.475795717384656e-08, 1200]], "6": [[0.0009948797403789844, 200], [0.0009948797403789844, 400], [0.0009948797403789844, 600], [7.446019733625686e-06, 800], [2.8334836261190155e-06, 1000], [2.8334836261190155e-06, 1200]], "7": [[2.6953738685442374e-09, 200], [2.6953738685442374e-09, 400], [2.6032551114774094e-09, 600], [2.6032551114774094e-09, 800], [2.290168055196773e-12, 1000], [2.290168055196773e-12, 1200]], "8": [[0.0016936464836114218, 200], [0.0016936464836114218, 400], [0.0016936464836114218, 600], [0.0016936464836114218, 800], [0.0016936464836114218, 1000], [0.0016936464836114218, 1200]], "9": [[6.010530961830796e-11, 200], [6.010530961830796e-11, 400], [6.010530961830796e-11, 600], [6.010530961830796e-11, 800], [6.010530961830796e-11, 1000], [6.010530961830796e-11, 1200]]}

# %%
import matplotlib.pyplot as plt
from math import e
e
# Out:
# 2.718281828459045

# %%
axes = plt.gca()
axes.set_xlim([200, 1200])
axes.set_ylim([e**-70,e**-(2.5)])
for x in data:
    best, iteration = [], []
    for value in data[x]:
        best.append(value[0])
        iteration.append(value[1])
    plt.plot(iteration, best, linewidth=1)
#     plt.legend(["logistic","chebyshev","gauss","piecewise","singer","tent","iterative","sine","circle","sinusoidal",], loc='upper right')
plt.savefig('graph.png')
plt.show()
